# %%
import pandas as pd

books = pd.read_csv("data/books.csv")
ratings = pd.read_csv("data/ratings.csv")

# %% [markdown]
# ## Collaborative Filtering by model (SVD)

# %%
import numpy as np
from scipy.sparse.linalg import svds
from scipy.linalg import sqrtm

# Création de la table user // book avec les notes déjà données
R_df = ratings.pivot(index="user_id",columns="book_id",values="rating").fillna(0)

# on récupère seulement les valeurs pour le svds
R = R_df.values

# Calcul la moyenne des notes mise par chaque user, pour la retirer (on la rajoutera à la fin)
user_ratings_mean = np.mean(R, axis=1)
user_ratings_mean = np.float16(user_ratings_mean)
R_demeaned = R - user_ratings_mean.reshape(-1, 1)

latent_dimension = 90 # Après une étude sur cette valeur (de 90 à 110) et sur l'erreur myenne et écart type prediction - note réelle, on a décidé de prendre 90 (rapport erreur/temps de calcul)

U, sigma, Vt = svds(R_demeaned, k=latent_dimension) 

sigma = np.diag(sigma)
s_root = sqrtm(sigma)

Usk = np.dot(U, s_root)
Usk = np.float16(Usk) # Passage float64 à float16

skV = np.dot(s_root, Vt)
skV = np.float16(skV) # Passage float64 à float16

predicted_rating = np.dot(Usk, skV) # Calcul des notes de chaque user pour chaque livre

predicted_rating = predicted_rating + user_ratings_mean.reshape(-1, 1) # On rajoute la moyenne

preds_df = pd.DataFrame(predicted_rating, columns=R_df.columns, index=R_df.index)

# %%
def get_book_name(book_id):
    # Fonction qui récupère le titre du livre grâce à son id
    book_name = books["title"][books["book_id"]==book_id].item()
    return book_name

def recommandation(user, preds_df=preds_df):
    # Fonction qui, pour un utilisateur, renvoie la liste de ses 10 livres préférés (meilleures notes) ainsi que les 10 livres qui lui sont le plus recommandés

    list_recommandations = []

    # Récupère la ligne qui correspond à l'user dans les notes originales et les notes prédites
    original_ratings = R_df.loc[user]
    pred_ratings = preds_df.loc[user]

    prefered_books = pred_ratings[original_ratings!=0].sort_values(axis=0, ascending=False)
    pred_ratings = pred_ratings[original_ratings==0].sort_values(axis=0, ascending=False) # On garde les note qui n'étaient pas présentes dans les notes originales et on les trie

    # On récupère les indices (= id) des 10 premiers 
    list_prefered = list(prefered_books[0:10].index)
    list_recommandations = list(pred_ratings[0:10].index)

    # On récupère leurs noms
    list_prefered = list(map(get_book_name,list_prefered))
    list_recommandations = list(map(get_book_name,list_recommandations))

    return list_prefered, list_recommandations

for i in range(1,10):
    list_prefered, list_recommandations = recommandation(user=i)
    print("User n°",i)
    print("Livres préférés :")
    print(list_prefered)

    print("\nLivres recommandés :")
    print(list_recommandations)
    print("_______________\n")
# Out:
# User n° 1
# Livres préférés :
# ['To Kill a Mockingbird', 'The Kite Runner', 'Memoirs of a Geisha', 'Pride and Prejudice', 'The Girl with the Dragon Tattoo (Millennium, #1)', 'A Thousand Splendid Suns', 'The Help', 'Life of Pi', "Ender's Game (Ender's Saga, #1)", 'The Alchemist']
#
# Livres recommandés :
# ['Anna Karenina', 'The Little Prince', 'Wuthering Heights', 'The Guernsey Literary and Potato Peel Pie Society', 'Cutting for Stone', 'A Tree Grows in Brooklyn', 'The Joy Luck Club', 'The Other Boleyn Girl (The Plantagenet and Tudor Novels, #9)', "My Sister's Keeper", 'The Road']
# _______________
#
# User n° 2
# Livres préférés :
# ['Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)', 'Harry Potter and the Goblet of Fire (Harry Potter, #4)', 'Harry Potter and the Half-Blood Prince (Harry Potter, #6)', 'The Great Gatsby', 'Harry Potter and the Deathly Hallows (Harry Potter, #7)', 'Harry Potter and the Chamber of Secrets (Harry Potter, #2)', 'Harry Potter and the Order of the Phoenix (Harry Potter, #5)', "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)", 'The Diary of a Young Girl', 'The Tipping Point: How Little Things Can Make a Big Difference']
#
# Livres recommandés :
# ['Freakonomics: A Rogue Economist Explores the Hidden Side of Everything (Freakonomics, #1)', 'The Alchemist', 'Little Women (Little Women, #1)', 'Of Mice and Men', 'Jane Eyre', 'The 7 Habits of Highly Effective People: Powerful Lessons in Personal Change', 'Eat, Pray, Love', 'The Adventures of Huckleberry Finn', 'Night (The Night Trilogy #1)', 'Wuthering Heights']
# _______________
#
# User n° 3
# Livres préférés :
# ['To Kill a Mockingbird', 'The Diary of a Young Girl', '1984', 'Of Mice and Men', 'Lord of the Flies', "Charlotte's Web", "The Handmaid's Tale", 'Brave New World', 'The Joy Luck Club', 'The Adventures of Huckleberry Finn']
#
# Livres recommandés :
# ['Animal Farm', 'Night (The Night Trilogy #1)', 'The Color Purple', 'The Grapes of Wrath', 'Where the Sidewalk Ends', 'Romeo and Juliet', 'The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1)', 'The Poisonwood Bible', "Angela's Ashes (Frank McCourt, #1)", 'Beloved']
# _______________
#
# User n° 4
# Livres préférés :
# ['Harry Potter and the Goblet of Fire (Harry Potter, #4)', 'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)', 'Harry Potter and the Half-Blood Prince (Harry Potter, #6)', 'Harry Potter and the Chamber of Secrets (Harry Potter, #2)', 'Harry Potter and the Deathly Hallows (Harry Potter, #7)', 'Harry Potter and the Order of the Phoenix (Harry Potter, #5)', "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)", 'Of Mice and Men', 'The Giver (The Giver, #1)', "Ender's Game (Ender's Saga, #1)"]
#
# Livres recommandés :
# ['Jane Eyre', 'The Witches', 'The Princess Bride ', 'East of Eden', 'The Client', 'The Curious Incident of the Dog in the Night-Time', 'The Andromeda Strain', 'The Pelican Brief', 'A Light in the Attic', 'The Runaway Jury']
# _______________
#
# User n° 5
# Livres préférés :
# ['The Fault in Our Stars', 'The Ocean at the End of the Lane', "The Cuckoo's Calling (Cormoran Strike, #1)", 'Big Little Lies', 'Me Before You (Me Before You, #1)', 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children, #1)', 'Eleanor & Park', 'The Silkworm (Cormoran Strike, #2)', 'Station Eleven', 'Mr. Mercedes (Bill Hodges Trilogy, #1)']
#
# Livres recommandés :
# ['Gone Girl', 'The Girl on the Train', 'The Martian', 'Dark Places', 'Sharp Objects', 'The Shining (The Shining #1)', '11/22/63', 'The Lovely Bones', 'All the Light We Cannot See', 'Ready Player One']
# _______________
#
# User n° 6
# Livres préférés :
# ['Into the Wild', 'Into Thin Air: A Personal Account of the Mount Everest Disaster', 'The Devil in the White City: Murder, Magic, and Madness at the Fair That Changed America', 'A Walk in the Woods', 'One Hundred Years of Solitude', 'In Cold Blood', 'Middlesex', 'The Curious Incident of the Dog in the Night-Time', 'The Poisonwood Bible', 'Under the Banner of Heaven: A Story of Violent Faith']
#
# Livres recommandés :
# ['Me Talk Pretty One Day', 'Freakonomics: A Rogue Economist Explores the Hidden Side of Everything (Freakonomics, #1)', 'The Tipping Point: How Little Things Can Make a Big Difference', 'Blink: The Power of Thinking Without Thinking', 'Outliers: The Story of Success', 'Dress Your Family in Corduroy and Denim', 'Naked', "Angela's Ashes (Frank McCourt, #1)", 'Unbroken: A World War II Story of Survival, Resilience, and Redemption', 'The Little Prince']
# _______________
#
# User n° 7
# Livres préférés :
# ['American Gods (American Gods, #1)', 'Dune (Dune Chronicles #1)', 'Fahrenheit 451', 'Lord of the Flies', 'Matilda', '1984', 'Neverwhere', 'Brave New World', 'Of Mice and Men', 'The Lion, the Witch, and the Wardrobe (Chronicles of Narnia, #1)']
#
# Livres recommandés :
# ["Ender's Game (Ender's Saga, #1)", 'Romeo and Juliet', 'Charlie and the Chocolate Factory (Charlie Bucket, #1)', 'Slaughterhouse-Five', 'Animal Farm', 'Foundation (Foundation #1)', 'The Gunslinger (The Dark Tower, #1)', 'The Adventures of Huckleberry Finn', 'The Eye of the World (Wheel of Time, #1)', 'Stranger in a Strange Land']
# _______________
#
# User n° 8
# Livres préférés :
# ['1984', 'Animal Farm', 'Crime and Punishment', 'Brave New World', 'The Stranger', 'To Kill a Mockingbird', 'The Great Gatsby', 'Frankenstein', 'The Odyssey', 'The Brothers Karamazov']
#
# Livres recommandés :
# ['The Picture of Dorian Gray', 'The Metamorphosis', 'Anna Karenina', 'Lolita', 'The Old Man and the Sea', 'The Iliad', 'Siddhartha', 'The Count of Monte Cristo', 'Great Expectations', 'War and Peace']
# _______________
#
# User n° 9
# Livres préférés :
# ['1984', 'Me Talk Pretty One Day', 'The Great Gatsby', 'Eclipse (Twilight, #3)', 'Harry Potter and the Deathly Hallows (Harry Potter, #7)', 'Memoirs of a Geisha', 'Harry Potter and the Half-Blood Prince (Harry Potter, #6)', 'New Moon (Twilight, #2)', 'The Hunger Games (The Hunger Games, #1)', 'Twilight (Twilight, #1)']
#
# Livres recommandés :
# ['The Catcher in the Rye', 'When You Are Engulfed in Flames', 'Jane Eyre', 'The Road', 'A Heartbreaking Work of Staggering Genius', 'The Poisonwood Bible', 'Love in the Time of Cholera', 'Never Let Me Go', 'The Amazing Adventures of Kavalier & Clay', 'Into the Wild']
# _______________
