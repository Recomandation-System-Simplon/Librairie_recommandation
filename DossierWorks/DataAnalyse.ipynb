# %%
import pandas as pd

# %%
dataLibrairie = pd.read_excel("dataLibrairie.ods")
dataLibrairie=dataLibrairie.rename(columns={"ISBN":"isbn13"})
dataLibrairie
# Out:
#                                                   Titre             Auteur  \
# 0     Mondes Nouveaux - "L'Echec De Wilson" Et Autre...      Zweig/Magniez
# 1                                     Derniers Messages     Zweig/Le Rider
# 2                                               La Peur    Zweig/Deshusses
# 3     Le Desarroi Des Sentiments_1_Ere_Ed - Les Carn...    Zweig/Deshusses
# 4                                 Lettre D'Une Inconnue       Zweig Stefan
# ...                                                 ...                ...
# 7376                                  Le Retour Du Gang       Abbey Edward
# 7377                       Le Gang De La Clef A Molette       Abbey Edward
# 7378                            L'Oubli Que Nous Serons  Abad/Vargas Llosa
# 7379                     Carnet De Recettes Cornebidoui                NaN
# 7380                     Petit Cahier D'Activites Mange                NaN
#
#           Editeur         isbn13
# 0         Rivages  9782743651510
# ...

# %%
books = pd.read_csv("data/books.csv")
books
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
books.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %%
books.dtypes
# Out:
# book_id                        int64
# goodreads_book_id              int64
# best_book_id                   int64
# work_id                        int64
# books_count                    int64
# isbn                          object
# isbn13                       float64
# authors                       object
# original_publication_year    float64
# original_title                object
# title                         object
# language_code                 object
# average_rating               float64
# ratings_count                  int64
# work_ratings_count             int64
# work_text_reviews_count        int64
# ratings_1                      int64
# ratings_2                      int64
# ratings_3                      int64
# ratings_4                      int64
# ratings_5                      int64
# image_url                     object
# small_image_url               object
# dtype: object

# %%
def format_books(books):
    """La fonction format_books va nous permettre de supprimer 
    les colonnes dont on ne va pas se servir : liste_colonne_drop
    Mettre dans le bon format les données : int"""

    liste_colonne_drop = [
        "work_id",
        "books_count",
        "isbn",
        "average_rating",
        "language_code",
        "image_url",
        "small_image_url",
    ]

    data_books = books

    for i in liste_colonne_drop:
        data_books = data_books.drop(columns=i)

    data_books = data_books.dropna()
    data_books["isbn13"] = data_books["isbn13"].map(int)
    data_books["original_publication_year"] = data_books[
        "original_publication_year"
    ].map(int)

    return data_books

# %%
format_books(books).dtypes
# Out:
# book_id                       int64
# goodreads_book_id             int64
# best_book_id                  int64
# isbn13                        int64
# authors                      object
# original_publication_year     int64
# original_title               object
# title                        object
# ratings_count                 int64
# work_ratings_count            int64
# work_text_reviews_count       int64
# ratings_1                     int64
# ratings_2                     int64
# ratings_3                     int64
# ratings_4                     int64
# ratings_5                     int64
# dtype: object

# %%
book_tags = pd.read_csv("data/book_tags.csv")
book_tags
# Out:
#         goodreads_book_id  tag_id   count
# 0                       1   30574  167697
# 1                       1   11305   37174
# 2                       1   11557   34173
# 3                       1    8717   12986
# 4                       1   33114   12716
# ...                   ...     ...     ...
# 999907           33288638   21303       7
# 999908           33288638   17271       7
# 999909           33288638    1126       7
# 999910           33288638   11478       7
# 999911           33288638   27939       7
#
# [999912 rows x 3 columns]

# %%
ratings = pd.read_csv("data/ratings.csv")
ratings
# Out:
#          user_id  book_id  rating
# 0              1      258       5
# 1              2     4081       4
# 2              2      260       5
# 3              2     9296       5
# 4              2     2318       3
# ...          ...      ...     ...
# 5976474    49925      510       5
# 5976475    49925      528       4
# 5976476    49925      722       4
# 5976477    49925      949       5
# 5976478    49925     1023       4
#
# [5976479 rows x 3 columns]

# %%
ratings.dtypes
# Out:
# user_id    int64
# book_id    int64
# rating     int64
# dtype: object

# %%
tags = pd.read_csv("data/tags.csv")
tags["tag_name"][tags["tag_id"]==30574]
# Out:
# 30574    to-read
# Name: tag_name, dtype: object

# %%
tags.dtypes
# Out:
# tag_id       int64
# tag_name    object
# dtype: object

# %%
tags.head()
# Out:
#    tag_id tag_name
# 0       0        -
# 1       1     --1-
# 2       2    --10-
# 3       3    --12-
# 4       4   --122-

# %%
to_read = pd.read_csv("data/to_read.csv")
to_read
# Out:
#         user_id  book_id
# 0             9        8
# 1            15      398
# 2            15      275
# 3            37     7173
# 4            34      380
# ...         ...      ...
# 912700    39374     1049
# 912701    10492     5180
# 912702    21879     4827
# 912703    21879     6642
# 912704    48192     7773
#
# [912705 rows x 2 columns]

# %% [markdown]
# ## Réduire le nombre de tags par livre
# La liste des tags est extrèmement longue et difficile à nettoyer (il y a de l'Arabe, du Russe, des mots avec des "-" pour les sous-catégories...). Et le tableau d'association book_tags comporte 100 000 lignes. Notre but ici est de diminuer ce nombre, en prenant seulement les tags les plus nombreux et les plus significatifs.

# %%
book_tags = pd.read_csv("data/book_tags.csv")

# On garde seulement les tags que plus de 500 personnes ont mis à un livre
book_tags_trimmed = book_tags[book_tags["count"]>=110]

# On crée la liste des tags à supprimer car inutile pour Content-Based Filtering, mais on les gardera pour le Popularity Based
tag_names_supp = [
    "to-read",
    "currently-reading",
    "favorites", 
    "books-i-own",
    "owned",
    ]

# Fonction qui trouve le tag_id en fonction du tag_name
def get_tag_id(x):
    tag = tags.query('tag_name == "'+x+'"')['tag_id'].tolist()
    return tag[0]

tag_ids_supp=[]
 
for tag in tag_names_supp:
    tag_ids_supp.append(get_tag_id(tag))

# Boucle qui retire des book tags les tags_ids
for tag_id in tag_ids_supp:
    book_tags_trimmed = book_tags_trimmed[book_tags_trimmed["tag_id"]!=int(tag_id)]


# Fonction qui trouve le tag_name en fonction du tag_id
def get_tag_name(x):
    tag = tags.query('tag_id == '+str(x))['tag_name'].tolist()
    return tag[0]

# book_tags_trimmed["tag"]=book_tags_trimmed["tag_id"].apply(get_tag_name)

vc_tags_ids = pd.DataFrame(book_tags_trimmed["tag_id"].value_counts())

# %%
# Après le trim à 500, tous les livres sont-ils toujours là ?

for i in range(10,600,100):
    book_tags = pd.read_csv("data/book_tags.csv")

    book_tags_trimmed = book_tags[book_tags["count"]>=i]

    # Boucle qui retire des book tags les tags_ids
    for tag_id in tag_ids_supp:
        book_tags_trimmed = book_tags_trimmed[book_tags_trimmed["tag_id"]!=int(tag_id)]

    # book_tags_trimmed["tag"]=book_tags_trimmed["tag_id"].apply(get_tag_name)

    print(i, book_tags_trimmed["tag_id"].value_counts().size, book_tags_trimmed["goodreads_book_id"].value_counts().size)

    print("____________")
# Out:
# 10 13879 10000
# ____________
# 110 1903 9499
# ____________
# 210 1007 8500
# ____________
# 310 687 7372
# ____________
# 410 516 6326
# ____________
# 510 398 5483
# ____________

# %%
# Les genres qu'il reste
vc_tags_ids = pd.DataFrame(book_tags_trimmed["tag_id"].value_counts())
vc_tags_ids = vc_tags_ids.reset_index(inplace=False)
vc_tags_ids = vc_tags_ids.rename(columns={"tag_id":"count","index":"tag_id"})

vc_tags_ids["tag_name"]=vc_tags_ids["tag_id"].apply(get_tag_name)
vc_tags_ids.to_csv("data/value_counts_tags.csv")

""" 
Il reste 1900 tags pour les 9500 livres. Les plus nombreux (dans le haut ud tableau qui est value count) sont pour la plutpart intéressants (fantansy, sci-fi).
Les tags qui présentent seulement quelques dizaines d'occurences dans le value_count pourront être supprimés, et on triera le reste à la main ?
"""
# Out:
# " \nIl reste 1900 tags pour les 9500 livres. Les plus nombreux (dans le haut ud tableau qui est value count) sont pour la plutpart intéressants (fantansy, sci-fi).\nLes tags qui présentent seulement quelques dizaines d'occurences dans le value_count pourront être supprimés, et on triera le reste à la main ?\n"
